# %%
#importing necessary libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn import set_config
set_config(display='diagram')

from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder,MinMaxScaler

from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# %%
#loading dataset
df = pd.read_csv("/content/drive/MyDrive/credit_risk.csv")

# %% [markdown]
# Column Descriptions:
#
# * ID: Unique identifier for each loan applicant.
# * Age: Age of the loan applicant.
# * Income: Income of the loan applicant.
# * Home: Home ownership status (Own, Mortgage, Rent).
# * Emp_Length: Employment length in years.
# * Intent: Purpose of the loan (e.g., education, home improvement).
# * Amount: Loan amount applied for.
# * Rate: Interest rate on the loan.
# * Status: Loan approval status (Fully Paid, Charged Off, Current).
# * Percent_Income: Loan amount as a percentage of income.
# * Default: Whether the applicant has defaulted on a loan previously (Yes, No).
# * Cred_Length: Length of the applicant's credit history.

# %%
# Checking how dataset looks
df.head(10)
# Out:
#    Id  Age  Income      Home  Emp_length     Intent  Amount   Rate  Status  \
# 0   0   22   59000      RENT       123.0   PERSONAL   35000  16.02       1
# 1   1   21    9600       OWN         5.0  EDUCATION    1000  11.14       0
# 2   2   25    9600  MORTGAGE         1.0    MEDICAL    5500  12.87       1
# 3   3   23   65500      RENT         4.0    MEDICAL   35000  15.23       1
# 4   4   24   54400      RENT         8.0    MEDICAL   35000  14.27       1
# 5   5   21    9900       OWN         2.0    VENTURE    2500   7.14       1
# 6   6   26   77100      RENT         8.0  EDUCATION   35000  12.42       1
# 7   7   24   78956      RENT         5.0    MEDICAL   35000  11.11       1
# 8   8   24   83000      RENT         8.0   PERSONAL   35000   8.90       1
# 9   9   21   10000       OWN         6.0    VENTURE    1600  14.74       1
#
#    Percent_income Default  Cred_length
# 0            0.59       Y            3
# 1            0.10       N            2
# 2            0.57       N            3
# 3            0.53       N            2
# 4            0.55       Y            4
# 5            0.25       N            2
# 6            0.45       N            3
# 7            0.44       N            4
# 8            0.42       N            2
# 9            0.16       N            3

# %%
# checking shape of our dataset
df.shape
# Out:
# (32581, 12)

# %% [markdown]
# ## Our dataset have many rows 32581 which is considered a normal dataset for study purpose.

# %%
# using info function to check types of columns and null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32581 entries, 0 to 32580
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Id              32581 non-null  int64
#  1   Age             32581 non-null  int64
#  2   Income          32581 non-null  int64
#  3   Home            32581 non-null  object
#  4   Emp_length      31686 non-null  float64
#  5   Intent          32581 non-null  object
#  6   Amount          32581 non-null  int64
#  7   Rate            29465 non-null  float64
#  8   Status          32581 non-null  int64
#  9   Percent_income  32581 non-null  float64
#  10  Default         32581 non-null  object
#  11  Cred_length     32581 non-null  int64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 3.0+ MB

# %% [markdown]
# ## We have null values in 2 columns

# %%
# Finding value of null values
df.isnull().sum()
# Out:
# Id                   0
# Age                  0
# Income               0
# Home                 0
# Emp_length         895
# Intent               0
# Amount               0
# Rate              3116
# Status               0
# Percent_income       0
# Default              0
# Cred_length          0
# dtype: int64

# %%
# Visualizing null values using heatmap
sns.heatmap(df.isnull(),yticklabels = False, cbar = False,cmap = 'tab20c_r' )
# Out:
# <Axes: >

# %%
# Checking percentage of null values
null_values = (df.isnull().sum() / len(df)) * 100
null_values
# Out:
# Id                0.000000
# Age               0.000000
# Income            0.000000
# Home              0.000000
# Emp_length        2.747000
# Intent            0.000000
# Amount            0.000000
# Rate              9.563856
# Status            0.000000
# Percent_income    0.000000
# Default           0.000000
# Cred_length       0.000000
# dtype: float64

# %% [markdown]
# since we dont have higher percentage of null values we can easily drop them

# %%
# checking if dataset have any duplicate values
num_duplicate_rows = df.duplicated().sum()
num_duplicate_rows
# Out:
# 0

# %% [markdown]
# ## Checking distribution of the dataset columns

# %%
# Get all columns
columns = df.columns

# Set the figure size
plt.figure(figsize=(15, 15))

# Loop through each column and plot the histogram
for i, col in enumerate(columns):
    plt.subplot(4, 3, i + 1)  # Subplot arrangement with 4 rows and 3 columns for better visualization
    sns.histplot(df[col])
    plt.title(f'Histogram of {col}', fontsize=12)
    plt.xlabel(col, fontsize=10)
    plt.ylabel('Frequency', fontsize=10)
    plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Most of the numerical columns are skewed and target variable have binary values that are imbalance as well

# %%
#Finding unique values in columns
df.nunique()
# Out:
# Id                32581
# Age                  58
# Income             4295
# Home                  4
# Emp_length           36
# Intent                6
# Amount              753
# Rate                348
# Status                2
# Percent_income       77
# Default               2
# Cred_length          29
# dtype: int64

# %% [markdown]
# ## Checking percentage of unique values

# %%
# Iterate through all columns
for column in df.columns:
    # Get the value counts for the current column
    value_counts = df[column].value_counts()

    # Calculate the percentages
    percentages = (value_counts / len(df[column])) * 100

    # Create a DataFrame with the unique values, counts, and percentages
    result_df = pd.DataFrame({'Value': value_counts.index, 'Count': value_counts.values, 'Percentage': percentages.values})

    # Display the results for the current column
    print(f"\nUnique values and percentages for '{column}':")
    print(result_df)
# Out:
# Unique values and percentages for 'Id':
#        Value  Count  Percentage
# 0          0      1    0.003069
# 1      21717      1    0.003069
# 2      21730      1    0.003069
# 3      21729      1    0.003069
# 4      21728      1    0.003069
# ...      ...    ...         ...
# 32576  10855      1    0.003069
# 32577  10854      1    0.003069
# 32578  10853      1    0.003069
# 32579  10852      1    0.003069
# 32580  32780      1    0.003069
#
# [32581 rows x 3 columns]
#
# Unique values and percentages for 'Age':
#     Value  Count  Percentage
# 0      23   3889   11.936405
# 1      22   3633   11.150671
# 2      24   3549   10.892852
# 3      25   3037    9.321384
# 4      26   2477    7.602590
# 5      27   2138    6.562107
# 6      28   1854    5.690433
# 7      29   1687    5.177864
# 8      30   1316    4.039164
# 9      21   1229    3.772137
# 10     31   1142    3.505110
# 11     32    964    2.958780
# 12     33    856    2.627298
# 13     34    709    2.176115
# 14     35    620    1.902950
# 15     36    548    1.681962
# 16     37    478    1.467113
# 17     38    373    1.144839
# 18     39    302    0.926921
# 19     40    271    0.831773
# 20     41    241    0.739695
# 21     42    188    0.577023
# 22     43    164    0.503361
# 23     44    141    0.432768
# 24     45    108    0.331482
# 25     46     94    0.288512
# 26     47     94    0.288512
# 27     48     75    0.230196
# 28     50     52    0.159602
# 29     49     49    0.150394
# 30     51     39    0.119702
# 31     52     36    0.110494
# 32     53     30    0.092078
# 33     54     24    0.073663
# 34     55     20    0.061385
# 35     58     19    0.058316
# 36     56     15    0.046039
# 37     57     15    0.046039
# 38     20     15    0.046039
# 39     60     15    0.046039
# 40     65      9    0.027623
# 41     66      9    0.027623
# 42     61      9    0.027623
# 43     70      7    0.021485
# 44     64      7    0.021485
# 45     62      7    0.021485
# 46     59      5    0.015346
# 47     69      5    0.015346
# 48    144      3    0.009208
# 49     73      3    0.009208
# 50     63      3    0.009208
# 51    123      2    0.006139
# 52     78      1    0.003069
# 53     94      1    0.003069
# 54     80      1    0.003069
# 55     84      1    0.003069
# 56     76      1    0.003069
# 57     67      1    0.003069
#
# Unique values and percentages for 'Income':
#       Value  Count  Percentage
# 0     60000   1046    3.210460
# 1     30000    847    2.599675
# 2     50000    778    2.387895
# 3     40000    658    2.019582
# 4     45000    590    1.810871
# ...     ...    ...         ...
# 4290  54316      1    0.003069
# 4291  54480      1    0.003069
# 4292  72645      1    0.003069
# 4293  72893      1    0.003069
# 4294   4888      1    0.003069
#
# [4295 rows x 3 columns]
#
# Unique values and percentages for 'Home':
#       Value  Count  Percentage
# 0      RENT  16446   50.477272
# 1  MORTGAGE  13444   41.263313
# 2       OWN   2584    7.931003
# 3     OTHER    107    0.328412
#
# Unique values and percentages for 'Emp_length':
#     Value  Count  Percentage
# 0     0.0   4105   12.599368
# 1     2.0   3849   11.813634
# 2     3.0   3456   10.607409
# 3     5.0   2946    9.042080
# 4     1.0   2915    8.946932
# 5     4.0   2874    8.821092
# 6     6.0   2666    8.182683
# 7     7.0   2196    6.740125
# 8     8.0   1687    5.177864
# 9     9.0   1367    4.195697
# 10   11.0    740    2.271262
# 11   10.0    696    2.136214
# 12   12.0    575    1.764832
# 13   13.0    426    1.307511
# 14   14.0    335    1.028207
# 15   15.0    238    0.730487
# 16   16.0    165    0.506430
# 17   17.0    129    0.395936
# 18   18.0    104    0.319204
# 19   19.0     64    0.196434
# 20   20.0     42    0.128909
# 21   21.0     38    0.116632
# 22   22.0     19    0.058316
# 23   24.0     10    0.030693
# 24   23.0     10    0.030693
# 25   25.0      8    0.024554
# 26   26.0      6    0.018416
# 27   27.0      5    0.015346
# 28   31.0      4    0.012277
# 29   28.0      3    0.009208
# 30  123.0      2    0.006139
# 31   30.0      2    0.006139
# 32   41.0      1    0.003069
# 33   34.0      1    0.003069
# 34   29.0      1    0.003069
# 35   38.0      1    0.003069
#
# Unique values and percentages for 'Intent':
#                Value  Count  Percentage
# 0          EDUCATION   6453   19.806022
# 1            MEDICAL   6071   18.633559
# 2            VENTURE   5719   17.553175
# 3           PERSONAL   5521   16.945459
# 4  DEBTCONSOLIDATION   5212   15.997053
# 5    HOMEIMPROVEMENT   3605   11.064731
#
# Unique values and percentages for 'Amount':
#      Value  Count  Percentage
# 0    10000   2664    8.176545
# 1     5000   2043    6.270526
# 2    12000   1809    5.552316
# 3     6000   1801    5.527762
# 4    15000   1502    4.610049
# ..     ...    ...         ...
# 748  27300      1    0.003069
# 749  17325      1    0.003069
# 750   9625      1    0.003069
# 751   4525      1    0.003069
# 752  29850      1    0.003069
#
# [753 rows x 3 columns]
#
# Unique values and percentages for 'Rate':
#      Value  Count  Percentage
# 0     7.51    756    2.320371
# 1    10.99    749    2.298886
# 2     7.49    645    1.979681
# 3     7.88    642    1.970474
# 4     5.42    594    1.823148
# ..     ...    ...         ...
# 343  21.64      1    0.003069
# 344  20.48      1    0.003069
# 345  17.46      1    0.003069
# 346  21.14      1    0.003069
# 347  20.53      1    0.003069
#
# [348 rows x 3 columns]
#
# Unique values and percentages for 'Status':
#    Value  Count  Percentage
# 0      0  25473   78.183604
# 1      1   7108   21.816396
#
# Unique values and percentages for 'Percent_income':
#     Value  Count  Percentage
# 0    0.10   1533    4.705196
# 1    0.13   1482    4.548663
# 2    0.08   1437    4.410546
# 3    0.07   1394    4.278567
# 4    0.11   1381    4.238667
# ..    ...    ...         ...
# 72   0.62      1    0.003069
# 73   0.76      1    0.003069
# 74   0.83      1    0.003069
# 75   0.72      1    0.003069
# 76   0.78      1    0.003069
#
# [77 rows x 3 columns]
#
# Unique values and percentages for 'Default':
#   Value  Count  Percentage
# 0     N  26836   82.367024
# 1     Y   5745   17.632976
#
# Unique values and percentages for 'Cred_length':
#     Value  Count  Percentage
# 0       2   5965   18.308216
# 1       3   5943   18.240692
# 2       4   5925   18.185446
# 3       8   1902    5.837758
# 4       7   1901    5.834689
# 5       9   1895    5.816273
# 6       5   1881    5.773303
# 7       6   1857    5.699641
# 8      10   1850    5.678156
# 9      14    492    1.510083
# 10     12    485    1.488598
# 11     11    463    1.421074
# 12     16    451    1.384242
# 13     13    443    1.359688
# 14     15    437    1.341273
# 15     17    407    1.249194
# 16     20     31    0.095147
# 17     24     30    0.092078
# 18     28     27    0.082870
# 19     27     22    0.067524
# 20     22     22    0.067524
# 21     23     22    0.067524
# 22     30     22    0.067524
# 23     19     21    0.064455
# 24     21     20    0.061385
# 25     18     19    0.058316
# 26     25     18    0.055247
# 27     26     16    0.049108
# 28     29     14    0.042970

# %% [markdown]
# ## Data is diverse

# %%
#Finding outliers using boxplot
plt.subplots(figsize=(12, 8))
sns.boxplot(data=df, orient='v')
plt.xticks(rotation=90, ha='right')
plt.show()

# %% [markdown]
# ## Income column have many outliers. We will first fix this column and check how many outliers other columns have

# %%
#Since Id column isn't useful we will drop it
df.drop(columns=["Id"],axis=1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-118-b968105c05d1> in <cell line: 2>()
#       1 #Since Id column isn't useful we will drop it
# ----> 2 df.drop(columns=["Id"],axis=1, inplace = True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503         for axis, labels in axes.items():
#    4504             if labels is not None:
# -> 4505                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4506
#    4507         if inplace:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4544                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4545             else:
# -> 4546                 new_axis = axis.drop(labels, errors=errors)
#    4547             indexer = axis.get_indexer(new_axis)
#    4548
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6932         if mask.any():
#    6933             if errors != "ignore":
# -> 6934                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935             indexer = indexer[~mask]
#    6936         return self.delete(indexer)
#
# KeyError: "['Id'] not found in axis"

# %%
# Finding min, max and mean values to understand how numerical values are distributed
df.describe()
# Out:
#                 Age        Income    Emp_length        Amount          Rate  \
# count  32581.000000  3.258100e+04  31686.000000  32581.000000  29465.000000
# mean      27.734600  6.607485e+04      4.789686   9589.371106     11.011695
# std        6.348078  6.198312e+04      4.142630   6322.086646      3.240459
# min       20.000000  4.000000e+03      0.000000    500.000000      5.420000
# 25%       23.000000  3.850000e+04      2.000000   5000.000000      7.900000
# 50%       26.000000  5.500000e+04      4.000000   8000.000000     10.990000
# 75%       30.000000  7.920000e+04      7.000000  12200.000000     13.470000
# max      144.000000  6.000000e+06    123.000000  35000.000000     23.220000
#
#              Status  Percent_income   Cred_length
# count  32581.000000    32581.000000  32581.000000
# mean       0.218164        0.170203      5.804211
# std        0.413006        0.106782      4.055001
# min        0.000000        0.000000      2.000000
# 25%        0.000000        0.090000      3.000000
# 50%        0.000000        0.150000      4.000000
# 75%        0.000000        0.230000      8.000000
# max        1.000000        0.830000     30.000000

# %%
# Finding rows that have higher than 60000000 income
specific_row = df[df['Income'] >= 6000000]
specific_row
# Out:
#        Age   Income      Home  Emp_length    Intent  Amount   Rate  Status  \
# 32297  144  6000000  MORTGAGE        12.0  PERSONAL    5000  12.73       0
#
#        Percent_income Default  Cred_length
# 32297             0.0       N           25

# %%
# Finding rows that have higher than 20000000 income
specific_row = df[df['Income'] >= 2000000]
specific_row
# Out:
#        Age   Income      Home  Emp_length    Intent  Amount   Rate  Status  \
# 30049   42  2039784      RENT         0.0   VENTURE    8450  12.29       0
# 32297  144  6000000  MORTGAGE        12.0  PERSONAL    5000  12.73       0
#
#        Percent_income Default  Cred_length
# 30049             0.0       Y           15
# 32297             0.0       N           25

# %% [markdown]
# ## There is only one row with 6000000 value as income and Age is 144 for this row as well, whole row could be a human error we will remove it as its way faraway from rest of the points in dataset.

# %%
# Removing row with 6000000 value
df = df[df['Income'] < 6000000]

# %%
# Finding rows that have higher than 90 Age
specific_row = df[df['Age'] >= 90]
specific_row
# Out:
#        Age  Income      Home  Emp_length     Intent  Amount   Rate  Status  \
# 81     144  250000      RENT         4.0    VENTURE    4800  13.57       0
# 183    144  200000  MORTGAGE         4.0  EDUCATION    6000  11.86       0
# 575    123   80004      RENT         2.0  EDUCATION   20400  10.25       0
# 747    123   78000      RENT         7.0    VENTURE   20000    NaN       0
# 32416   94   24000      RENT         1.0    MEDICAL    6500    NaN       0
#
#        Percent_income Default  Cred_length
# 81               0.02       N            3
# 183              0.03       N            2
# 575              0.25       N            3
# 747              0.26       N            4
# 32416            0.27       N           27

# %%
# Removing row with 90+ Age
df = df[df['Age'] < 90]

# %%
# Finding rows that have higher than 60 employment length
specific_row = df[df['Emp_length'] >= 60]
specific_row
# Out:
#      Age  Income      Home  Emp_length    Intent  Amount   Rate  Status  \
# 0     22   59000      RENT       123.0  PERSONAL   35000  16.02       1
# 210   21  192000  MORTGAGE       123.0   VENTURE   20000   6.54       0
#
#      Percent_income Default  Cred_length
# 0              0.59       Y            3
# 210            0.10       N            4

# %%
# Removing row with 100+ Emp_length
df = df[df['Emp_length'] < 100]

# %%
df.describe().T
# Out:
#                   count          mean           std      min       25%  \
# Age             31678.0     27.728581      6.202358    20.00     23.00
# Income          31678.0  66491.440495  52769.086293  4000.00  39396.00
# Emp_length      31678.0      4.782183      4.034956     0.00      2.00
# Amount          31678.0   9660.062188   6334.435654   500.00   5000.00
# Rate            28632.0     11.039701      3.229409     5.42      7.90
# Status          31678.0      0.215449      0.411140     0.00      0.00
# Percent_income  31678.0      0.169607      0.106269     0.00      0.09
# Cred_length     31678.0      5.808542      4.058028     2.00      3.00
#
#                      50%       75%         max
# Age                26.00     30.00       84.00
# Income          56000.00  80000.00  2039784.00
# Emp_length          4.00      7.00       41.00
# Amount           8000.00  12500.00    35000.00
# Rate               10.99     13.48       23.22
# Status              0.00      0.00        1.00
# Percent_income      0.15      0.23        0.83
# Cred_length         4.00      8.00       30.00

# %%
# Finding rows that have 0 value
specific_row = df[df['Percent_income'] == 0 ]
specific_row
# Out:
#        Age   Income      Home  Emp_length             Intent  Amount   Rate  \
# 17834   34   948000  MORTGAGE        18.0           PERSONAL    2000   9.99
# 18917   35   510000      RENT         1.0           PERSONAL    1800  13.48
# 27877   30   522000  MORTGAGE        11.0    HOMEIMPROVEMENT    2500   7.43
# 30049   42  2039784      RENT         0.0            VENTURE    8450  12.29
# 31916   43   780000  MORTGAGE         2.0    HOMEIMPROVEMENT    1000   8.94
# 31922   47  1362000  MORTGAGE         9.0            VENTURE    6600   7.74
# 31924   44  1440000  MORTGAGE         7.0  DEBTCONSOLIDATION    6400   7.40
# 32546   60  1900000  MORTGAGE         5.0           PERSONAL    1500    NaN
#
#        Status  Percent_income Default  Cred_length
# 17834       0             0.0       N            7
# 18917       0             0.0       N            6
# 27877       0             0.0       N            9
# 30049       0             0.0       Y           15
# 31916       0             0.0       N           11
# 31922       0             0.0       N           17
# 31924       0             0.0       N           15
# 32546       0             0.0       N           21

# %% [markdown]
# ## Only 7 rows have 0 value so we can remove it

# %%
# Removing row with 0 values in Percent_income
df = df[df['Percent_income'] > 0]

# %%
# Finding rows that have 0 value in Employment length
specific_row = df[df['Emp_length'] == 0]
specific_row
# Out:
#        Age  Income      Home  Emp_length             Intent  Amount   Rate  \
# 16      23  120000      RENT         0.0          EDUCATION   35000   7.90
# 23      24   10980       OWN         0.0           PERSONAL    1500   7.29
# 27      23   11000       OWN         0.0           PERSONAL    1400   9.32
# 45      26  300000  MORTGAGE         0.0          EDUCATION   25000  15.33
# 49      26   89028      RENT         0.0  DEBTCONSOLIDATION   30000   6.62
# ...    ...     ...       ...         ...                ...     ...    ...
# 32563   52   71520      RENT         0.0          EDUCATION    7000  16.82
# 32564   53   45000      RENT         0.0           PERSONAL    5600  13.79
# 32572   52   52000       OWN         0.0           PERSONAL    9600   8.49
# 32573   56   90000  MORTGAGE         0.0           PERSONAL    7200   6.17
# 32575   52   64500      RENT         0.0          EDUCATION    5000  11.26
#
#        Status  Percent_income Default  Cred_length
# 16          0            0.29       N            4
# 23          0            0.14       N            3
# 27          0            0.13       N            3
# 45          0            0.08       N            3
# 49          1            0.34       N            3
# ...       ...             ...     ...          ...
# 32563       1            0.10       Y           24
# 32564       0            0.12       N           28
# 32572       0            0.18       N           22
# 32573       0            0.08       N           19
# 32575       0            0.08       N           20
#
# [4104 rows x 11 columns]

# %% [markdown]
# ## 4105 is higher number we will impute this column with median cause our dataset is skewed and we didn't remove all the outliers.

# %%
# Imputing missing values
trf1 = ColumnTransformer([
    ('Emp_length',SimpleImputer(strategy='median'),[3]),
    ('Rate',SimpleImputer(strategy='median'),[6])
],remainder='passthrough')

# %%
df.describe().T
# Out:
#                   count          mean           std      min       25%  \
# Age             31670.0     27.725008      6.197508    20.00     23.00
# Income          31670.0  66208.211809  48889.154819  4000.00  39329.25
# Emp_length      31670.0      4.781718      4.034366     0.00      2.00
# Amount          31670.0   9661.547206   6334.401178   500.00   5000.00
# Rate            28625.0     11.040051      3.229533     5.42      7.90
# Status          31670.0      0.215504      0.411178     0.00      0.00
# Percent_income  31670.0      0.169650      0.106248     0.01      0.09
# Cred_length     31670.0      5.806820      4.056347     2.00      3.00
#
#                      50%       75%         max
# Age                26.00     30.00       84.00
# Income          56000.00  80000.00  1782000.00
# Emp_length          4.00      7.00       41.00
# Amount           8000.00  12500.00    35000.00
# Rate               10.99     13.48       23.22
# Status              0.00      0.00        1.00
# Percent_income      0.15      0.23        0.83
# Cred_length         4.00      8.00       30.00

# %%
df.shape
# Out:
# (31670, 11)

# %%
df.head(10)
# Out:
#     Age  Income      Home  Emp_length     Intent  Amount   Rate  Status  \
# 1    21    9600       OWN         5.0  EDUCATION    1000  11.14       0
# 2    25    9600  MORTGAGE         1.0    MEDICAL    5500  12.87       1
# 3    23   65500      RENT         4.0    MEDICAL   35000  15.23       1
# 4    24   54400      RENT         8.0    MEDICAL   35000  14.27       1
# 5    21    9900       OWN         2.0    VENTURE    2500   7.14       1
# 6    26   77100      RENT         8.0  EDUCATION   35000  12.42       1
# 7    24   78956      RENT         5.0    MEDICAL   35000  11.11       1
# 8    24   83000      RENT         8.0   PERSONAL   35000   8.90       1
# 9    21   10000       OWN         6.0    VENTURE    1600  14.74       1
# 10   22   85000      RENT         6.0    VENTURE   35000  10.37       1
#
#     Percent_income Default  Cred_length
# 1             0.10       N            2
# 2             0.57       N            3
# 3             0.53       N            2
# 4             0.55       Y            4
# 5             0.25       N            2
# 6             0.45       N            3
# 7             0.44       N            4
# 8             0.42       N            2
# 9             0.16       N            3
# 10            0.41       N            4

# %%
df["Status"].value_counts().plot(kind="pie", autopct ="%.2f'", cmap= 'tab20c')
# Out:
# <Axes: ylabel='Status'>

# %%
# Relationship between Home and Default
sns.countplot(x='Home', hue='Status' , data=df)
# Out:
# <Axes: xlabel='Home', ylabel='count'>

# %%
# Relationship between Home and Status in percentage
grouped_data = df.groupby('Status')['Home'].value_counts(normalize=True).unstack(fill_value=0) * 100
grouped_data
# Out:
# Home     MORTGAGE     OTHER       OWN       RENT
# Status
# 0       46.101831  0.297847  9.027973  44.572349
# 1       23.882784  0.483516  2.446886  73.186813

# %%
# Relationship between Intent and status
sns.countplot(x='Intent', hue='Status' , data=df)
# Out:
# <Axes: xlabel='Intent', ylabel='count'>

# %%
# Relationship between Intent and Status in percentage
grouped_data = df.groupby('Status')['Intent'].value_counts(normalize=True).unstack(fill_value=0) * 100
grouped_data
# Out:
# Intent  DEBTCONSOLIDATION  EDUCATION  HOMEIMPROVEMENT    MEDICAL   PERSONAL  \
# Status
# 0               14.594486  21.018314        10.509157  17.432079  17.379754
# 1               21.054945  15.619048        13.142857  22.930403  15.326007
#
# Intent    VENTURE
# Status
# 0       19.066211
# 1       11.926740

# %%
# Relationship between Status and Default
sns.countplot(x='Status', hue='Default' , data=df)
# Out:
# <Axes: xlabel='Status', ylabel='count'>

# %%
# Relationship between Status and Default in percentage
grouped_data = df.groupby('Status')['Default'].value_counts(normalize=True).unstack(fill_value=0) * 100
grouped_data
# Out:
# Default          N          Y
# Status
# 0        85.860903  14.139097
# 1        69.025641  30.974359

# %%
# Relationship of Credit length with Default and Status
sns.stripplot(x='Status', y='Cred_length', hue='Default', data=df)
# Out:
# <Axes: xlabel='Status', ylabel='Cred_length'>

# %%
# Relationship of Rate with Default and Status
sns.stripplot(x='Status', y='Rate', hue='Default', data=df)
# Out:
# <Axes: xlabel='Status', ylabel='Rate'>

# %%
# Relationship of Percent Income with Default and Status
sns.stripplot(x='Status', y='Percent_income', hue='Default', data=df)
# Out:
# <Axes: xlabel='Status', ylabel='Percent_income'>

# %%
# Relationship of Amount with Default and Status
sns.stripplot(x='Status', y='Amount', hue='Default', data=df)
# Out:
# <Axes: xlabel='Status', ylabel='Amount'>

# %%
# Relationship of Income with Default and Status
sns.stripplot(x='Status', y='Income', hue='Default', data=df)
# Out:
# <Axes: xlabel='Status', ylabel='Income'>

# %%
# Relationship of Age with Default and Status
sns.stripplot(x='Status', y='Age', hue='Default', data=df)
# Out:
# <Axes: xlabel='Status', ylabel='Age'>

# %% [markdown]
# ## We have 3 categorical columns and we will do encoding for them

# %%
# one hot encoding
trf2 = ColumnTransformer([
    ('ohe_home_intent_default',OneHotEncoder(sparse=False,handle_unknown='ignore'),[2,4,9])
],remainder='passthrough')

# %%
df.head(10)
# Out:
#     Age  Income      Home  Emp_length     Intent  Amount   Rate  Status  \
# 1    21    9600       OWN         5.0  EDUCATION    1000  11.14       0
# 2    25    9600  MORTGAGE         1.0    MEDICAL    5500  12.87       1
# 3    23   65500      RENT         4.0    MEDICAL   35000  15.23       1
# 4    24   54400      RENT         8.0    MEDICAL   35000  14.27       1
# 5    21    9900       OWN         2.0    VENTURE    2500   7.14       1
# 6    26   77100      RENT         8.0  EDUCATION   35000  12.42       1
# 7    24   78956      RENT         5.0    MEDICAL   35000  11.11       1
# 8    24   83000      RENT         8.0   PERSONAL   35000   8.90       1
# 9    21   10000       OWN         6.0    VENTURE    1600  14.74       1
# 10   22   85000      RENT         6.0    VENTURE   35000  10.37       1
#
#     Percent_income Default  Cred_length
# 1             0.10       N            2
# 2             0.57       N            3
# 3             0.53       N            2
# 4             0.55       Y            4
# 5             0.25       N            2
# 6             0.45       N            3
# 7             0.44       N            4
# 8             0.42       N            2
# 9             0.16       N            3
# 10            0.41       N            4

# %%
#Finding correlation
plt.figure(figsize=(15, 10))
sns.heatmap(df.corr(),cbar=True,annot=True,cmap='Blues',fmt= '.2f')
# Out:
# <ipython-input-81-5c5c72d3d15c>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),cbar=True,annot=True,cmap='Blues',fmt= '.2f')
# <Axes: >

# %% [markdown]
# ## Age and Credit Length are highly correlated and contributes slightly with our Target feature so we will drop one of them

# %%
df.drop(columns=["Cred_length"],axis=1, inplace = True)

# %%
df.sample(10)
# Out:
#        Age  Income      Home  Emp_length             Intent  Amount   Rate  \
# 16903   22   71500      RENT         2.0          EDUCATION    6400  13.11
# 17274   23   53352      RENT         3.0            MEDICAL   17500   6.54
# 18483   33  130000      RENT         1.0          EDUCATION   20000   6.62
# 2359    25   32000  MORTGAGE         8.0  DEBTCONSOLIDATION    5600   7.90
# 21926   27   89700      RENT         1.0            VENTURE    6000  11.99
# 15003   25   52000      RENT         4.0          EDUCATION   15000  12.18
# 13242   23   90000  MORTGAGE         7.0            VENTURE    4900   6.99
# 2443    23   26500      RENT         1.0          EDUCATION    2800  12.29
# 12352   26   80000  MORTGAGE         5.0            VENTURE    3000   8.00
# 18845   35   27600  MORTGAGE        19.0          EDUCATION    3000  11.86
#
#        Status  Percent_income Default
# 16903       0            0.09       N
# 17274       1            0.33       N
# 18483       0            0.15       N
# 2359        0            0.17       N
# 21926       0            0.07       N
# 15003       0            0.29       N
# 13242       0            0.05       N
# 2443        0            0.11       N
# 12352       0            0.04       N
# 18845       0            0.11       N

# %%
#splitting dataset into train and test
X = df.drop('Status', axis = 1) # grabs everything else but 'Default'
y = df['Status'] # y is the column we're trying to predict

# %%
X
# Out:
#        Age  Income      Home  Emp_length           Intent  Amount   Rate  \
# 1       21    9600       OWN         5.0        EDUCATION    1000  11.14
# 2       25    9600  MORTGAGE         1.0          MEDICAL    5500  12.87
# 3       23   65500      RENT         4.0          MEDICAL   35000  15.23
# 4       24   54400      RENT         8.0          MEDICAL   35000  14.27
# 5       21    9900       OWN         2.0          VENTURE    2500   7.14
# ...    ...     ...       ...         ...              ...     ...    ...
# 32576   57   53000  MORTGAGE         1.0         PERSONAL    5800  13.16
# 32577   54  120000  MORTGAGE         4.0         PERSONAL   17625   7.49
# 32578   65   76000      RENT         3.0  HOMEIMPROVEMENT   35000  10.99
# 32579   56  150000  MORTGAGE         5.0         PERSONAL   15000  11.48
# 32580   66   42000      RENT         2.0          MEDICAL    6475   9.99
#
#        Percent_income Default
# 1                0.10       N
# 2                0.57       N
# 3                0.53       N
# 4                0.55       Y
# 5                0.25       N
# ...               ...     ...
# 32576            0.11       N
# 32577            0.15       N
# 32578            0.46       N
# 32579            0.10       N
# 32580            0.15       N
#
# [31670 rows x 9 columns]

# %%
y
# Out:
# 1        0
# 2        1
# 3        1
# 4        1
# 5        1
#         ..
# 32576    0
# 32577    0
# 32578    1
# 32579    0
# 32580    0
# Name: Status, Length: 31670, dtype: int64

# %% [markdown]
# ## Scaling features of dataset because they have huge difference in their units and ML model can be biased towards higher value features

# %%
# Scaling
trf3 = ColumnTransformer([
    ('scale',MinMaxScaler(),slice(0,10))
])

# %%
# Splitting dataset into train and test for training model
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = .20, random_state = 42)

# %%
trf4 = Pipeline([
    ('dtc', DecisionTreeClassifier())
])

# %%
trf5 = Pipeline([
    ('lrc', LogisticRegression())
])

# %%
trf6 = Pipeline([
    ('rfc', RandomForestClassifier())
])

# %%
trf7 = Pipeline([
    ('gbc', GradientBoostingClassifier())
])

# %%
#Create Pipeline
pipe = Pipeline([
    ('trf1',trf1),
    ('trf2',trf2),
    ('trf3',trf3),
    ('trf4',trf4),
    ('trf5',trf5),
    ('trf6',trf6),
    ('trf7',trf7)
])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-117-56b8c9a3d173> in <cell line: 2>()
#       1 #Create Pipeline
# ----> 2 pipe = make_Pipeline([
#       3     ('trf1',trf1),
#       4     ('trf2',trf2),
#       5     ('trf3',trf3),
#
# NameError: name 'make_Pipeline' is not defined

# %%
pipe.named_steps
# Out:
# {'trf1': ColumnTransformer(remainder='passthrough',
#                    transformers=[('Emp_length', SimpleImputer(strategy='median'),
#                                   [3]),
#                                  ('Rate', SimpleImputer(strategy='median'),
#                                   [6])]),
#  'trf2': ColumnTransformer(remainder='passthrough',
#                    transformers=[('ohe_home_intent_default',
#                                   OneHotEncoder(handle_unknown='ignore',
#                                                 sparse=False),
#                                   [2, 4, 9])]),
#  'trf3': ColumnTransformer(transformers=[('scale', MinMaxScaler(), slice(0, 10, None))]),
#  'trf4': Pipeline(steps=[('dtc', DecisionTreeClassifier())]),
#  'trf5': Pipeline(steps=[('lrc', LogisticRegression())]),
#  'trf6': Pipeline(steps=[('rfc', RandomForestClassifier())]),
#  'trf7': Pipeline(steps=[('gbc', GradientBoostingClassifier())])}

# %%
# train
pipe.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-116-a78d51bdc8e1> in <cell line: 2>()
#       1 # train
# ----> 2 pipe.fit(x_train,y_train)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py in fit(self, X, y, **fit_params)
#     399         """
#     400         fit_params_steps = self._check_fit_params(**fit_params)
# --> 401         Xt = self._fit(X, y, **fit_params_steps)
#     402         with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#     403             if self._final_estimator != "passthrough":
#
# /usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py in _fit(self, X, y, **fit_params_steps)
#     337         # shallow copy of steps - this should really be steps_
#     338         self.steps = list(self.steps)
# --> 339         self._validate_steps()
#     340         # Setup the memory
#     341         memory = check_memory(self.memory)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py in _validate_steps(self)
#     228                 t, "transform"
#     229             ):
# --> 230                 raise TypeError(
#     231                     "All intermediate steps should be "
#     232                     "transformers and implement fit and transform "
#
# TypeError: All intermediate steps should be transformers and implement fit and transform or be the string 'passthrough' 'Pipeline(steps=[('dtc', DecisionTreeClassifier())])' (type <class 'sklearn.pipeline.Pipeline'>) doesn't

# %% [markdown]
# # **1. LOGISTIC REGRESSION**

# %% [markdown]
# ## **Model Training**

# %%
log_reg = LogisticRegression()
log_reg.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ## **Model Evaluation**

# %%
y_pred_log_reg = log_reg.predict(x_test)
log_reg_accuracy = round(accuracy_score(y_test, y_pred_log_reg),2)
print('Accuracy', log_reg_accuracy,'%')

classification_rep = classification_report(y_test, y_pred_log_reg)
print("Classification Report:\n", classification_rep)

confusion = confusion_matrix(y_test, y_pred_log_reg)
print(confusion)
sns.heatmap(confusion, annot=True, fmt="d",
            xticklabels=['Predicted Negative', 'Predicted Positive'],
            yticklabels=['Actual Negative', 'Actual Positive'])
plt.title("Confusion Matrix for Logistic Regression")
plt.xlabel("Predicted Values")
plt.ylabel("Actual Values")
plt.show()
# Out:
# Accuracy 0.84 %
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.96      0.90      4963
#            1       0.73      0.42      0.53      1371
#
#     accuracy                           0.84      6334
#    macro avg       0.79      0.69      0.72      6334
# weighted avg       0.83      0.84      0.82      6334
#
# [[4752  211]
#  [ 798  573]]

# %% [markdown]
# # **2. DECISION TREE**

# %% [markdown]
# ## **Model Training**

# %%
Dtree = DecisionTreeClassifier()
Dtree.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ## **Model Evalution**

# %%
y_pred_Dtree = Dtree.predict(x_test)
Dtree_accuracy = round(accuracy_score(y_test, y_pred_Dtree) ,2)
print('Accuracy', Dtree_accuracy,'%')

classification_rep = classification_report(y_test, y_pred_Dtree)
print("Classification Report:\n", classification_rep)

confusion = confusion_matrix(y_test, y_pred_Dtree)
print(confusion)
sns.heatmap(confusion, annot=True, fmt="d",
            xticklabels=['Predicted Negative', 'Predicted Positive'],
            yticklabels=['Actual Negative', 'Actual Positive'])
plt.title("Confusion Matrix for Logistic Regression")
plt.xlabel("Predicted Values")
plt.ylabel("Actual Values")
plt.show()
# Out:
# Accuracy 0.87 %
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.92      0.92      4963
#            1       0.70      0.69      0.69      1371
#
#     accuracy                           0.87      6334
#    macro avg       0.81      0.80      0.80      6334
# weighted avg       0.87      0.87      0.87      6334
#
# [[4554  409]
#  [ 426  945]]

# %% [markdown]
# # **3. RANDOM FOREST**

# %% [markdown]
# ## **Model Training**

# %%
rfc = RandomForestClassifier()
rfc.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# ## **Model Evaluation**

# %%
y_pred_rfc = rfc.predict(x_test)
rfc_accuracy = round(accuracy_score(y_test, y_pred_rfc) * 100,2)
print('Accuracy', rfc_accuracy,'%')

classification_rep = classification_report(y_test, y_pred_rfc)
print("Classification Report:\n", classification_rep)

confusion = confusion_matrix(y_test, y_pred_rfc)
print(confusion)
sns.heatmap(confusion, annot=True, fmt="d",
            xticklabels=['Predicted Negative', 'Predicted Positive'],
            yticklabels=['Actual Negative', 'Actual Positive'])
plt.title("Confusion Matrix for Logistic Regression")
plt.xlabel("Predicted Values")
plt.ylabel("Actual Values")
plt.show()
# Out:
# Accuracy 91.06 %
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95      4963
#            1       0.93      0.64      0.76      1371
#
#     accuracy                           0.91      6334
#    macro avg       0.92      0.81      0.85      6334
# weighted avg       0.91      0.91      0.90      6334
#
# [[4893   70]
#  [ 496  875]]

# %% [markdown]
# # **4. GRADIENT BOOSTING CLASSIFIER**

# %% [markdown]
# ## **Model Training**

# %%
gbc = GradientBoostingClassifier()
gbc.fit(x_train, y_train)
# Out:
# GradientBoostingClassifier()

# %% [markdown]
# ## **Model Evalution**

# %%
y_pred_gbc = gbc.predict(x_test)
gbc_accuracy = round(accuracy_score(y_test, y_pred_gbc),2)
print('Accuracy', gbc_accuracy,'%')

classification_rep = classification_report(y_test, y_pred_gbc)
print("Classification Report:\n", classification_rep)

confusion = confusion_matrix(y_test, y_pred_gbc)
print(confusion)
sns.heatmap(confusion, annot=True, fmt="d",
            xticklabels=['Predicted Negative', 'Predicted Positive'],
            yticklabels=['Actual Negative', 'Actual Positive'])
plt.title("Confusion Matrix for Logistic Regression")
plt.xlabel("Predicted Values")
plt.ylabel("Actual Values")
plt.show()
# Out:
# Accuracy 0.9 %
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94      4963
#            1       0.91      0.60      0.73      1371
#
#     accuracy                           0.90      6334
#    macro avg       0.90      0.79      0.83      6334
# weighted avg       0.90      0.90      0.89      6334
#
# [[4877   86]
#  [ 542  829]]

# %%
data = [
{
        'Model': 'Logistic Regression',
        'Accuracy': 0.82,
        'Precision': 0.48,
        'Recall': 0.29,
        'Confusion Matrix': [[4431,  303],
                                 [ 708,  283]]
    },
    {
        'Model': 'Decision Tree',
        'Accuracy': 0.81,
        'Precision': 0.47,
        'Recall': 0.50,
        'Confusion Matrix': [[4189,  545],[ 498,  493]]
    },
    {
        'Model': 'Random Forest',
        'Accuracy': 0.82,
        'Precision': 0.50,
        'Recall': 0.47,
        'Confusion Matrix': [[4263,  471],[ 527,  464]]
    },
    {
        'Model': 'Gradient Boosting',
        'Accuracy': 0.82,
        'Precision': 0.50,
        'Recall': 0.56,
        'Confusion Matrix': [[4188,  546],[ 439,  552]]
    }
]

results_df = pd.DataFrame(data)

# %%
results_df
# Out:
#                  Model  Accuracy  Precision  Recall           Confusion Matrix
# 0  Logistic Regression      0.82       0.48    0.29  [[4431, 303], [708, 283]]
# 1        Decision Tree      0.81       0.47    0.50  [[4189, 545], [498, 493]]
# 2        Random Forest      0.82       0.50    0.47  [[4263, 471], [527, 464]]
# 3    Gradient Boosting      0.82       0.50    0.56  [[4188, 546], [439, 552]]

# %% [markdown]
# ## Since Gradient Boosting did perform well on our dataset we would use it to tunning

# %%
# from sklearn.model_selection import GridSearchCV

# # Define the parameter grid for GridSearchCV
# param_grid = {
#     'n_estimators': [100, 200, 500],
#     'learning_rate': [0.01, 0.1, 1],
#     'max_depth': [3, 5, 8],
#     'min_samples_split': [2, 5, 10],
#     'max_features': ['sqrt', 'log2']
# }

# # Create a GradientBoostingClassifier instance
# gbr = GradientBoostingClassifier(random_state=42)

# # Apply GridSearchCV with stratified k-fold cross-validation
# gbr_cv = GridSearchCV(gbr, param_grid, cv=5, scoring='accuracy', n_jobs=-1)

# # Fit the GridSearchCV model
# gbr_cv.fit(x_train, y_train)

# # Get the best model and parameters
# best_model = gbr_cv.best_estimator_
# best_params = gbr_cv.best_params_

# # Print the best model and parameters
# print("Best model: ", best_model)
# print("Best parameters: ", best_params)

# # Evaluate the best model's performance on held-out data (assuming you have one)
# y_pred = best_model.predict(x_test)
# accuracy = accuracy_score(y_test, y_pred)
# print("Accuracy on test data:", accuracy)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-71-668dd4714a98> in <cell line: 19>()
#      17
#      18 # Fit the GridSearchCV model
# ---> 19 gbr_cv.fit(x_train, y_train)
#      20
#      21 # Get the best model and parameters
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     872                 return results
#     873
# --> 874             self._run_search(evaluate_candidates)
#     875
#     876             # multimetric is determined here because in the case of a callable
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1386     def _run_search(self, evaluate_candidates):
#    1387         """Search all candidates in param_grid"""
# -> 1388         evaluate_candidates(ParameterGrid(self.param_grid))
#    1389
#    1390
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     819                     )
#     820
# --> 821                 out = parallel(
#     822                     delayed(_fit_and_score)(
#     823                         clone(base_estimator),
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py in __call__(self, iterable)
#      61             for delayed_func, args, kwargs in iterable
#      62         )
# ---> 63         return super().__call__(iterable_with_config)
#      64
#      65
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1950         next(output)
#    1951
# -> 1952         return output if self.return_generator else list(output)
#    1953
#    1954     def __repr__(self):
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in _get_outputs(self, iterator, pre_dispatch)
#    1593
#    1594             with self._backend.retrieval_context():
# -> 1595                 yield from self._retrieve()
#    1596
#    1597         except GeneratorExit:
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in _retrieve(self)
#    1705                 (self._jobs[0].get_status(
#    1706                     timeout=self.timeout) == TASK_PENDING)):
# -> 1707                 time.sleep(0.01)
#    1708                 continue
#    1709
#
# KeyboardInterrupt:
